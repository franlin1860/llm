# %% [markdown]
# <a href="https://colab.research.google.com/github/franlin1860/llm/blob/main/advanced_text_to_sql_v20240909.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Workflows for Advanced Text-to-SQL
#
# <a href="https://colab.research.google.com/github/jerryjliu/llama_index/blob/main/docs/docs/examples/workflow/advanced_text_to_sql.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# In this guide we show you how to setup a text-to-SQL workflow over your data with our [workflows](https://docs.llamaindex.ai/en/stable/module_guides/workflow/#workflows) syntax.
#
# This gives you flexibility to enhance text-to-SQL with additional techniques. We show these in the below sections:
# 1. **Query-Time Table Retrieval**: Dynamically retrieve relevant tables in the text-to-SQL prompt.
# 2. **Query-Time Sample Row retrieval**: Embed/Index each row, and dynamically retrieve example rows for each table in the text-to-SQL prompt.
#
# Our out-of-the box workflows include our `NLSQLTableQueryEngine` and `SQLTableRetrieverQueryEngine`. (if you want to check out our text-to-SQL guide using these modules, take a look [here](https://docs.llamaindex.ai/en/stable/examples/index_structs/struct_indices/SQLIndexDemo.html)). This guide implements an advanced version of those modules, giving you the utmost flexibility to apply this to your own setting.
#
# **NOTE:** Any Text-to-SQL application should be aware that executing
# arbitrary SQL queries can be a security risk. It is recommended to
# take precautions as needed, such as using restricted roles, read-only
# databases, sandboxing, etc.

# %% [markdown]
# # Prevent Disconnection

# %%
#@markdown <h3>← 输入了代码后运行以防止断开</h>
import IPython
from google.colab import output

display(IPython.display.Javascript('''
 function ClickConnect(){
   btn = document.querySelector("colab-connect-button")
   if (btn != null){
     console.log("Click colab-connect-button");
     btn.click()
     }

   btn = document.getElementById('ok')
   if (btn != null){
     console.log("Click reconnect");
     btn.click()
     }
  }

setInterval(ClickConnect,60000)
'''))

print("Done.")
# Out:
# Done.

# %%
function ConnectButton(){
    console.log("Connect pushed");
    document.querySelector("#connect").click()
}
setInterval(ConnectButton,60000);

# %% [markdown]
# # LLM Setup

# %%
# !pip install llama-index
# !pip install llama_index-llms-openai_like
# !pip install llama_index-embeddings-huggingface
# Out:
# Collecting llama-index
#   Downloading llama_index-0.11.7-py3-none-any.whl.metadata (11 kB)
# Collecting llama-index-agent-openai<0.4.0,>=0.3.1 (from llama-index)
#   Downloading llama_index_agent_openai-0.3.1-py3-none-any.whl.metadata (677 bytes)
# Collecting llama-index-cli<0.4.0,>=0.3.0 (from llama-index)
#   Downloading llama_index_cli-0.3.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting llama-index-core<0.12.0,>=0.11.7 (from llama-index)
#   Downloading llama_index_core-0.11.7-py3-none-any.whl.metadata (2.4 kB)
# Collecting llama-index-embeddings-openai<0.3.0,>=0.2.4 (from llama-index)
#   Downloading llama_index_embeddings_openai-0.2.4-py3-none-any.whl.metadata (635 bytes)
# Collecting llama-index-indices-managed-llama-cloud>=0.3.0 (from llama-index)
#   Downloading llama_index_indices_managed_llama_cloud-0.3.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting llama-index-legacy<0.10.0,>=0.9.48 (from llama-index)
#   Downloading llama_index_legacy-0.9.48.post3-py3-none-any.whl.metadata (8.5 kB)
# Collecting llama-index-llms-openai<0.3.0,>=0.2.3 (from llama-index)
#   Downloading llama_index_llms_openai-0.2.3-py3-none-any.whl.metadata (654 bytes)
# Collecting llama-index-multi-modal-llms-openai<0.3.0,>=0.2.0 (from llama-index)
#   Downloading llama_index_multi_modal_llms_openai-0.2.0-py3-none-any.whl.metadata (728 bytes)
# Collecting llama-index-program-openai<0.3.0,>=0.2.0 (from llama-index)
#   Downloading llama_index_program_openai-0.2.0-py3-none-any.whl.metadata (766 bytes)
# Collecting llama-index-question-gen-openai<0.3.0,>=0.2.0 (from llama-index)
#   Downloading llama_index_question_gen_openai-0.2.0-py3-none-any.whl.metadata (785 bytes)
# Collecting llama-index-readers-file<0.3.0,>=0.2.0 (from llama-index)
#   Downloading llama_index_readers_file-0.2.1-py3-none-any.whl.metadata (5.4 kB)
# Collecting llama-index-readers-llama-parse>=0.3.0 (from llama-index)
#   Downloading llama_index_readers_llama_parse-0.3.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting nltk>3.8.1 (from llama-index)
#   Downloading nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting openai>=1.14.0 (from llama-index-agent-openai<0.4.0,>=0.3.1->llama-index)
#   Downloading openai-1.44.0-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: PyYAML>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.7->llama-index) (2.0.32)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index) (3.10.5)
# Collecting dataclasses-json (from llama-index-core<0.12.0,>=0.11.7->llama-index)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting deprecated>=1.2.9.3 (from llama-index-core<0.12.0,>=0.11.7->llama-index)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting dirtyjson<2.0.0,>=1.0.8 (from llama-index-core<0.12.0,>=0.11.7->llama-index)
#   Downloading dirtyjson-1.0.8-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index) (2024.6.1)
# Collecting httpx (from llama-index-core<0.12.0,>=0.11.7->llama-index)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index) (3.3)
# Requirement already satisfied: numpy<2.0.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index) (9.4.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index) (2.8.2)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index) (2.32.3)
# Collecting tenacity!=8.4.0,<9.0.0,>=8.2.0 (from llama-index-core<0.12.0,>=0.11.7->llama-index)
#   Downloading tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting tiktoken>=0.3.3 (from llama-index-core<0.12.0,>=0.11.7->llama-index)
#   Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index) (4.12.2)
# Collecting typing-inspect>=0.8.0 (from llama-index-core<0.12.0,>=0.11.7->llama-index)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index) (1.16.0)
# Collecting llama-cloud>=0.0.11 (from llama-index-indices-managed-llama-cloud>=0.3.0->llama-index)
#   Downloading llama_cloud-0.0.17-py3-none-any.whl.metadata (751 bytes)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2.1.4)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-readers-file<0.3.0,>=0.2.0->llama-index) (4.12.3)
# Collecting pypdf<5.0.0,>=4.0.1 (from llama-index-readers-file<0.3.0,>=0.2.0->llama-index)
#   Downloading pypdf-4.3.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting striprtf<0.0.27,>=0.0.26 (from llama-index-readers-file<0.3.0,>=0.2.0->llama-index)
#   Downloading striprtf-0.0.26-py3-none-any.whl.metadata (2.1 kB)
# Collecting llama-parse>=0.5.0 (from llama-index-readers-llama-parse>=0.3.0->llama-index)
#   Downloading llama_parse-0.5.2-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index) (2024.5.15)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index) (4.0.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.3.0,>=0.2.0->llama-index) (2.6)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.12.0,>=0.11.7->llama-index) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.12.0,>=0.11.7->llama-index) (2024.8.30)
# Collecting httpcore==1.* (from httpx->llama-index-core<0.12.0,>=0.11.7->llama-index)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.12.0,>=0.11.7->llama-index) (3.8)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.12.0,>=0.11.7->llama-index) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.7->llama-index)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1.14.0->llama-index-agent-openai<0.4.0,>=0.3.1->llama-index) (1.7.0)
# Collecting jiter<1,>=0.4.0 (from openai>=1.14.0->llama-index-agent-openai<0.4.0,>=0.3.1->llama-index)
#   Downloading jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.7->llama-index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.7->llama-index) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.7->llama-index) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.7->llama-index) (2.0.7)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.7->llama-index) (3.0.3)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.7->llama-index)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->llama-index-core<0.12.0,>=0.11.7->llama-index)
#   Downloading marshmallow-3.22.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2024.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->llama-index-core<0.12.0,>=0.11.7->llama-index) (1.2.2)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.12.0,>=0.11.7->llama-index) (24.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (1.16.0)
# Downloading llama_index-0.11.7-py3-none-any.whl (6.8 kB)
# Downloading llama_index_agent_openai-0.3.1-py3-none-any.whl (13 kB)
# Downloading llama_index_cli-0.3.0-py3-none-any.whl (27 kB)
# Downloading llama_index_core-0.11.7-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 20.1 MB/s eta 0:00:00
# Downloading llama_index_embeddings_openai-0.2.4-py3-none-any.whl (6.1 kB)
# Downloading llama_index_indices_managed_llama_cloud-0.3.0-py3-none-any.whl (9.5 kB)
# Downloading llama_index_legacy-0.9.48.post3-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 49.9 MB/s eta 0:00:00
# Downloading llama_index_llms_openai-0.2.3-py3-none-any.whl (12 kB)
# Downloading llama_index_multi_modal_llms_openai-0.2.0-py3-none-any.whl (5.9 kB)
# Downloading llama_index_program_openai-0.2.0-py3-none-any.whl (5.3 kB)
# Downloading llama_index_question_gen_openai-0.2.0-py3-none-any.whl (2.9 kB)
# Downloading llama_index_readers_file-0.2.1-py3-none-any.whl (38 kB)
# Downloading llama_index_readers_llama_parse-0.3.0-py3-none-any.whl (2.5 kB)
# Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 50.6 MB/s eta 0:00:00
# Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Downloading dirtyjson-1.0.8-py3-none-any.whl (25 kB)
# Downloading llama_cloud-0.0.17-py3-none-any.whl (187 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.4/187.4 kB 12.9 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 5.3 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.0 MB/s eta 0:00:00
# Downloading llama_parse-0.5.2-py3-none-any.whl (9.5 kB)
# Downloading openai-1.44.0-py3-none-any.whl (367 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 367.8/367.8 kB 18.1 MB/s eta 0:00:00
# Downloading pypdf-4.3.1-py3-none-any.whl (295 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.8/295.8 kB 16.6 MB/s eta 0:00:00
# Downloading striprtf-0.0.26-py3-none-any.whl (6.9 kB)
# Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 44.0 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (318 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 19.7 MB/s eta 0:00:00
# Downloading marshmallow-3.22.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 3.2 MB/s eta 0:00:00
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.7 MB/s eta 0:00:00
# Installing collected packages: striprtf, dirtyjson, tenacity, pypdf, nltk, mypy-extensions, marshmallow, jiter, h11, deprecated, typing-inspect, tiktoken, httpcore, httpx, dataclasses-json, openai, llama-index-core, llama-cloud, llama-parse, llama-index-readers-file, llama-index-legacy, llama-index-indices-managed-llama-cloud, llama-index-embeddings-openai, llama-index-readers-llama-parse, llama-index-llms-openai, llama-index-agent-openai, llama-index-program-openai, llama-index-question-gen-openai, llama-index-multi-modal-llms-openai, llama-index-cli, llama-index
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.8.1
#     Uninstalling nltk-3.8.1:
#       Successfully uninstalled nltk-3.8.1
# Successfully installed dataclasses-json-0.6.7 deprecated-1.2.14 dirtyjson-1.0.8 h11-0.14.0 httpcore-1.0.5 httpx-0.27.2 jiter-0.5.0 llama-cloud-0.0.17 llama-index-0.11.7 llama-index-agent-openai-0.3.1 llama-index-cli-0.3.0 llama-index-core-0.11.7 llama-index-embeddings-openai-0.2.4 llama-index-indices-managed-llama-cloud-0.3.0 llama-index-legacy-0.9.48.post3 llama-index-llms-openai-0.2.3 llama-index-multi-modal-llms-openai-0.2.0 llama-index-program-openai-0.2.0 llama-index-question-gen-openai-0.2.0 llama-index-readers-file-0.2.1 llama-index-readers-llama-parse-0.3.0 llama-parse-0.5.2 marshmallow-3.22.0 mypy-extensions-1.0.0 nltk-3.9.1 openai-1.44.0 pypdf-4.3.1 striprtf-0.0.26 tenacity-8.5.0 tiktoken-0.7.0 typing-inspect-0.9.0
# Collecting llama_index-llms-openai_like
#   Downloading llama_index_llms_openai_like-0.2.0-py3-none-any.whl.metadata (753 bytes)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from llama_index-llms-openai_like) (0.11.7)
# Requirement already satisfied: llama-index-llms-openai<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from llama_index-llms-openai_like) (0.2.3)
# Requirement already satisfied: transformers<5.0.0,>=4.37.0 in /usr/local/lib/python3.10/dist-packages (from llama_index-llms-openai_like) (4.44.2)
# Requirement already satisfied: PyYAML>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (2.0.32)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (3.10.5)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (2024.6.1)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (3.3)
# Requirement already satisfied: nltk>3.8.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (3.9.1)
# Requirement already satisfied: numpy<2.0.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (9.4.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (2.8.2)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (1.16.0)
# Requirement already satisfied: llama-index-agent-openai<0.4.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-llms-openai<0.3.0,>=0.2.0->llama_index-llms-openai_like) (0.3.1)
# Requirement already satisfied: openai<2.0.0,>=1.40.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-llms-openai<0.3.0,>=0.2.0->llama_index-llms-openai_like) (1.44.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.37.0->llama_index-llms-openai_like) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.37.0->llama_index-llms-openai_like) (0.24.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.37.0->llama_index-llms-openai_like) (24.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.37.0->llama_index-llms-openai_like) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.37.0->llama_index-llms-openai_like) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.37.0->llama_index-llms-openai_like) (0.19.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (4.0.3)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (1.4.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai<0.3.0,>=0.2.0->llama_index-llms-openai_like) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai<0.3.0,>=0.2.0->llama_index-llms-openai_like) (1.7.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai<0.3.0,>=0.2.0->llama_index-llms-openai_like) (0.5.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai<0.3.0,>=0.2.0->llama_index-llms-openai_like) (1.3.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (1.0.5)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (3.8)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (2.0.7)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama_index-llms-openai_like) (3.22.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.40.0->llama-index-llms-openai<0.3.0,>=0.2.0->llama_index-llms-openai_like) (1.2.2)
# Downloading llama_index_llms_openai_like-0.2.0-py3-none-any.whl (3.1 kB)
# Installing collected packages: llama_index-llms-openai_like
# Successfully installed llama_index-llms-openai_like-0.2.0
# Collecting llama_index-embeddings-huggingface
#   Downloading llama_index_embeddings_huggingface-0.3.1-py3-none-any.whl.metadata (718 bytes)
# Requirement already satisfied: huggingface-hub>=0.19.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub[inference]>=0.19.0->llama_index-embeddings-huggingface) (0.24.6)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from llama_index-embeddings-huggingface) (0.11.7)
# Collecting sentence-transformers>=2.6.1 (from llama_index-embeddings-huggingface)
#   Downloading sentence_transformers-3.0.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama_index-embeddings-huggingface) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama_index-embeddings-huggingface) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama_index-embeddings-huggingface) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama_index-embeddings-huggingface) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama_index-embeddings-huggingface) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama_index-embeddings-huggingface) (4.66.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama_index-embeddings-huggingface) (4.12.2)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from huggingface-hub[inference]>=0.19.0->llama_index-embeddings-huggingface) (3.10.5)
# Collecting minijinja>=1.0 (from huggingface-hub[inference]>=0.19.0->llama_index-embeddings-huggingface)
#   Downloading minijinja-2.2.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.8 kB)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama_index-embeddings-huggingface) (2.0.32)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index-embeddings-huggingface) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index-embeddings-huggingface) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index-embeddings-huggingface) (1.0.8)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index-embeddings-huggingface) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index-embeddings-huggingface) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index-embeddings-huggingface) (3.3)
# Requirement already satisfied: nltk>3.8.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index-embeddings-huggingface) (3.9.1)
# Requirement already satisfied: numpy<2.0.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index-embeddings-huggingface) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index-embeddings-huggingface) (9.4.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index-embeddings-huggingface) (2.8.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index-embeddings-huggingface) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index-embeddings-huggingface) (0.7.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index-embeddings-huggingface) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama_index-embeddings-huggingface) (1.16.0)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.6.1->llama_index-embeddings-huggingface) (4.44.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.6.1->llama_index-embeddings-huggingface) (2.4.0+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.6.1->llama_index-embeddings-huggingface) (1.3.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.6.1->llama_index-embeddings-huggingface) (1.13.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama_index-embeddings-huggingface) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama_index-embeddings-huggingface) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama_index-embeddings-huggingface) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama_index-embeddings-huggingface) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama_index-embeddings-huggingface) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama_index-embeddings-huggingface) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama_index-embeddings-huggingface) (4.0.3)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama_index-embeddings-huggingface) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama_index-embeddings-huggingface) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama_index-embeddings-huggingface) (2024.5.15)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama_index-embeddings-huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama_index-embeddings-huggingface) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama_index-embeddings-huggingface) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama_index-embeddings-huggingface) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama_index-embeddings-huggingface) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama_index-embeddings-huggingface) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama_index-embeddings-huggingface) (3.0.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama_index-embeddings-huggingface) (1.13.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama_index-embeddings-huggingface) (3.1.4)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers>=2.6.1->llama_index-embeddings-huggingface) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers>=2.6.1->llama_index-embeddings-huggingface) (0.19.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.0->llama_index-embeddings-huggingface) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama_index-embeddings-huggingface) (3.22.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama_index-embeddings-huggingface) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama_index-embeddings-huggingface) (1.0.5)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama_index-embeddings-huggingface) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.0->llama_index-embeddings-huggingface) (0.14.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers>=2.6.1->llama_index-embeddings-huggingface) (3.5.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->llama-index-core<0.12.0,>=0.11.0->llama_index-embeddings-huggingface) (1.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.1->llama_index-embeddings-huggingface) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers>=2.6.1->llama_index-embeddings-huggingface) (1.3.0)
# Downloading llama_index_embeddings_huggingface-0.3.1-py3-none-any.whl (8.6 kB)
# Downloading sentence_transformers-3.0.1-py3-none-any.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 5.8 MB/s eta 0:00:00
# Downloading minijinja-2.2.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (861 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 861.9/861.9 kB 24.1 MB/s eta 0:00:00
# Installing collected packages: minijinja, sentence-transformers, llama_index-embeddings-huggingface
# Successfully installed llama_index-embeddings-huggingface-0.3.1 minijinja-2.2.0 sentence-transformers-3.0.1

# %%
import os
os.environ["ZHIPU_API_KEY"] = ""

# %%
import os
import logging
import sys
from llama_index.llms.openai_like import OpenAILike
from llama_index.core import Settings, ServiceContext
from llama_index.embeddings.huggingface import HuggingFaceEmbedding

# 配置日志
logging.basicConfig(stream=sys.stdout, level=logging.INFO)

# 定义DeepSpeed model
llm = OpenAILike(model="glm-4-flash",
                 api_base="https://open.bigmodel.cn/api/paas/v4/",
                 api_key=os.environ["ZHIPU_API_KEY"],
                 temperature=0.6,
                 is_chat_model=True)

# 配置环境
Settings.llm = llm

# 设置嵌入模型
embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-small-zh-v1.5")
Settings.embed_model = embed_model
Settings.chunk_size = 256
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/27.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/95.8M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/367 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/110k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/439k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# ## Load and Ingest Data
#
#
# ### Load Data
# We use the [WikiTableQuestions dataset](https://ppasupat.github.io/WikiTableQuestions/) (Pasupat and Liang 2015) as our test dataset.
#
# We go through all the csv's in one folder, store each in a sqlite database (we will then build an object index over each table schema).

# %%
# !wget "https://github.com/ppasupat/WikiTableQuestions/releases/download/v1.0.2/WikiTableQuestions-1.0.2-compact.zip" -O data.zip
# !unzip data.zip
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#   inflating: WikiTableQuestions/csv/204-csv/553.tsv
#   inflating: WikiTableQuestions/csv/204-csv/147.html
#   inflating: WikiTableQuestions/csv/204-csv/774.table
#   inflating: WikiTableQuestions/csv/204-csv/986.csv
#   inflating: WikiTableQuestions/csv/204-csv/53.table
#   inflating: WikiTableQuestions/csv/204-csv/644.table
#   inflating: WikiTableQuestions/csv/204-csv/897.csv
#   inflating: WikiTableQuestions/csv/204-csv/648.html
#   inflating: WikiTableQuestions/csv/204-csv/653.html
#   inflating: WikiTableQuestions/csv/204-csv/808.table
#   inflating: WikiTableQuestions/csv/204-csv/389.html
#   inflating: WikiTableQuestions/csv/204-csv/96.table
#   inflating: WikiTableQuestions/csv/204-csv/981.csv
#   inflating: WikiTableQuestions/csv/204-csv/868.tsv
#   inflating: WikiTableQuestions/csv/204-csv/337.html
#   inflating: WikiTableQuestions/csv/204-csv/929.html
#   inflating: WikiTableQuestions/csv/204-csv/648.tsv
#   inflating: WikiTableQuestions/csv/204-csv/42.html
#   inflating: WikiTableQuestions/csv/204-csv/530.table
#   inflating: WikiTableQuestions/csv/204-csv/213.csv
#   inflating: WikiTableQuestions/csv/204-csv/323.html
#   inflating: WikiTableQuestions/csv/204-csv/892.tsv
#   inflating: WikiTableQuestions/csv/204-csv/331.table
#   inflating: WikiTableQuestions/csv/204-csv/471.html
#   inflating: WikiTableQuestions/csv/204-csv/33.tsv
#   inflating: WikiTableQuestions/csv/204-csv/590.html
#   inflating: WikiTableQuestions/csv/204-csv/454.csv
#   inflating: WikiTableQuestions/csv/204-csv/58.table
#   inflating: WikiTableQuestions/csv/204-csv/56.html
#   inflating: WikiTableQuestions/csv/204-csv/401.table
#   inflating: WikiTableQuestions/csv/204-csv/652.csv
#   inflating: WikiTableQuestions/csv/204-csv/363.csv
#   inflating: WikiTableQuestions/csv/204-csv/567.table
#   inflating: WikiTableQuestions/csv/204-csv/395.html
#   inflating: WikiTableQuestions/csv/204-csv/328.csv
#   inflating: WikiTableQuestions/csv/204-csv/391.tsv
#   inflating: WikiTableQuestions/csv/204-csv/824.tsv
#   inflating: WikiTableQuestions/csv/204-csv/923.csv
#   inflating: WikiTableQuestions/csv/204-csv/718.table
#   inflating: WikiTableQuestions/csv/204-csv/594.tsv
#   inflating: WikiTableQuestions/csv/204-csv/518.table
#   inflating: WikiTableQuestions/csv/204-csv/911.html
#   inflating: WikiTableQuestions/csv/204-csv/514.csv
#   inflating: WikiTableQuestions/csv/204-csv/901.table
#   inflating: WikiTableQuestions/csv/204-csv/615.tsv
#   inflating: WikiTableQuestions/csv/204-csv/819.html
#   inflating: WikiTableQuestions/csv/204-csv/665.table
#   inflating: WikiTableQuestions/csv/204-csv/921.table
#   inflating: WikiTableQuestions/csv/204-csv/495.table
#   inflating: WikiTableQuestions/csv/204-csv/996.html
#   inflating: WikiTableQuestions/csv/204-csv/161.table
#   inflating: WikiTableQuestions/csv/204-csv/933.table
#   inflating: WikiTableQuestions/csv/204-csv/555.html
#   inflating: WikiTableQuestions/csv/204-csv/993.table
#   inflating: WikiTableQuestions/csv/204-csv/355.table
#   inflating: WikiTableQuestions/csv/204-csv/832.csv
#   inflating: WikiTableQuestions/csv/204-csv/207.tsv
#   inflating: WikiTableQuestions/csv/204-csv/957.csv
#   inflating: WikiTableQuestions/csv/204-csv/883.tsv
#   inflating: WikiTableQuestions/csv/204-csv/337.csv
#   inflating: WikiTableQuestions/csv/204-csv/428.table
#   inflating: WikiTableQuestions/csv/204-csv/876.table
#   inflating: WikiTableQuestions/csv/204-csv/830.table
#   inflating: WikiTableQuestions/csv/204-csv/878.html
#   inflating: WikiTableQuestions/csv/204-csv/53.csv
#   inflating: WikiTableQuestions/csv/204-csv/929.tsv
#   inflating: WikiTableQuestions/csv/204-csv/250.tsv
#   inflating: WikiTableQuestions/csv/204-csv/266.tsv
#   inflating: WikiTableQuestions/csv/204-csv/112.html
#   inflating: WikiTableQuestions/csv/204-csv/881.tsv
#   inflating: WikiTableQuestions/csv/204-csv/149.tsv
#   inflating: WikiTableQuestions/csv/204-csv/539.csv
#   inflating: WikiTableQuestions/csv/204-csv/271.csv
#   inflating: WikiTableQuestions/csv/204-csv/258.table
#   inflating: WikiTableQuestions/csv/204-csv/785.csv
#   inflating: WikiTableQuestions/csv/204-csv/270.table
#   inflating: WikiTableQuestions/csv/204-csv/28.csv
#   inflating: WikiTableQuestions/csv/204-csv/340.table
#   inflating: WikiTableQuestions/csv/204-csv/488.table
#   inflating: WikiTableQuestions/csv/204-csv/92.tsv
#   inflating: WikiTableQuestions/csv/204-csv/874.table
#   inflating: WikiTableQuestions/csv/204-csv/8.table
#   inflating: WikiTableQuestions/csv/204-csv/361.csv
#   inflating: WikiTableQuestions/csv/204-csv/658.tsv
#   inflating: WikiTableQuestions/csv/204-csv/947.csv
#   inflating: WikiTableQuestions/csv/204-csv/231.tsv
#   inflating: WikiTableQuestions/csv/204-csv/103.html
#   inflating: WikiTableQuestions/csv/204-csv/372.html
#   inflating: WikiTableQuestions/csv/204-csv/729.table
#   inflating: WikiTableQuestions/csv/204-csv/382.csv
#   inflating: WikiTableQuestions/csv/204-csv/210.tsv
#   inflating: WikiTableQuestions/csv/204-csv/682.table
#   inflating: WikiTableQuestions/csv/204-csv/947.html
#   inflating: WikiTableQuestions/csv/204-csv/416.tsv
#   inflating: WikiTableQuestions/csv/204-csv/839.tsv
#   inflating: WikiTableQuestions/csv/204-csv/215.table
#   inflating: WikiTableQuestions/csv/204-csv/15.html
#   inflating: WikiTableQuestions/csv/204-csv/364.table
#   inflating: WikiTableQuestions/csv/204-csv/421.table
#   inflating: WikiTableQuestions/csv/204-csv/879.tsv
#   inflating: WikiTableQuestions/csv/204-csv/410.html
#   inflating: WikiTableQuestions/csv/204-csv/362.tsv
#   inflating: WikiTableQuestions/csv/204-csv/111.html
#   inflating: WikiTableQuestions/csv/204-csv/914.table
#   inflating: WikiTableQuestions/csv/204-csv/382.tsv
#   inflating: WikiTableQuestions/csv/204-csv/562.table
#   inflating: WikiTableQuestions/csv/204-csv/600.table
#   inflating: WikiTableQuestions/csv/204-csv/874.tsv
#   inflating: WikiTableQuestions/csv/204-csv/957.html
#   inflating: WikiTableQuestions/csv/204-csv/315.csv
#   inflating: WikiTableQuestions/csv/204-csv/103.csv
#   inflating: WikiTableQuestions/csv/204-csv/465.table
#   inflating: WikiTableQuestions/csv/204-csv/411.csv
#   inflating: WikiTableQuestions/csv/204-csv/948.table
#   inflating: WikiTableQuestions/csv/204-csv/533.html
#   inflating: WikiTableQuestions/csv/204-csv/774.csv
#   inflating: WikiTableQuestions/csv/204-csv/833.html
#   inflating: WikiTableQuestions/csv/204-csv/420.html
#   inflating: WikiTableQuestions/csv/204-csv/396.html
#   inflating: WikiTableQuestions/csv/204-csv/773.html
#   inflating: WikiTableQuestions/csv/204-csv/253.html
#   inflating: WikiTableQuestions/csv/204-csv/233.table
#   inflating: WikiTableQuestions/csv/204-csv/492.html
#   inflating: WikiTableQuestions/csv/204-csv/517.table
#   inflating: WikiTableQuestions/csv/204-csv/651.csv
#   inflating: WikiTableQuestions/csv/204-csv/17.table
#   inflating: WikiTableQuestions/csv/204-csv/316.csv
#   inflating: WikiTableQuestions/csv/204-csv/938.tsv
#   inflating: WikiTableQuestions/csv/204-csv/879.html
#   inflating: WikiTableQuestions/csv/204-csv/53.html
#   inflating: WikiTableQuestions/csv/204-csv/197.csv
#   inflating: WikiTableQuestions/csv/204-csv/647.html
#   inflating: WikiTableQuestions/csv/204-csv/640.tsv
#   inflating: WikiTableQuestions/csv/204-csv/814.table
#   inflating: WikiTableQuestions/csv/204-csv/286.html
#   inflating: WikiTableQuestions/csv/204-csv/865.html
#   inflating: WikiTableQuestions/csv/204-csv/9.table
#   inflating: WikiTableQuestions/csv/204-csv/88.csv
#   inflating: WikiTableQuestions/csv/204-csv/320.csv
#   inflating: WikiTableQuestions/csv/204-csv/496.csv
#   inflating: WikiTableQuestions/csv/204-csv/447.html
#   inflating: WikiTableQuestions/csv/204-csv/795.html
#   inflating: WikiTableQuestions/csv/204-csv/591.html
#   inflating: WikiTableQuestions/csv/204-csv/475.table
#   inflating: WikiTableQuestions/csv/204-csv/786.csv
#   inflating: WikiTableQuestions/csv/204-csv/848.table
#   inflating: WikiTableQuestions/csv/204-csv/469.html
#   inflating: WikiTableQuestions/csv/204-csv/301.table
#   inflating: WikiTableQuestions/csv/204-csv/823.table
#   inflating: WikiTableQuestions/csv/204-csv/861.tsv
#   inflating: WikiTableQuestions/csv/204-csv/258.html
#   inflating: WikiTableQuestions/csv/204-csv/526.html
#   inflating: WikiTableQuestions/csv/204-csv/85.csv
#   inflating: WikiTableQuestions/csv/204-csv/900.html
#   inflating: WikiTableQuestions/csv/204-csv/467.table
#   inflating: WikiTableQuestions/csv/204-csv/137.tsv
#   inflating: WikiTableQuestions/csv/204-csv/198.table
#   inflating: WikiTableQuestions/csv/204-csv/640.html
#   inflating: WikiTableQuestions/csv/204-csv/157.tsv
#   inflating: WikiTableQuestions/csv/204-csv/290.table
#   inflating: WikiTableQuestions/csv/204-csv/183.tsv
#   inflating: WikiTableQuestions/csv/204-csv/252.csv
#   inflating: WikiTableQuestions/csv/204-csv/473.tsv
#   inflating: WikiTableQuestions/csv/204-csv/264.tsv
#   inflating: WikiTableQuestions/csv/204-csv/431.tsv
#   inflating: WikiTableQuestions/csv/204-csv/789.csv
#   inflating: WikiTableQuestions/csv/204-csv/997.csv
#   inflating: WikiTableQuestions/csv/204-csv/87.table
#   inflating: WikiTableQuestions/csv/204-csv/820.csv
#   inflating: WikiTableQuestions/csv/204-csv/902.table
#   inflating: WikiTableQuestions/csv/204-csv/414.html
#   inflating: WikiTableQuestions/csv/204-csv/718.html
#   inflating: WikiTableQuestions/csv/204-csv/139.html
#   inflating: WikiTableQuestions/csv/204-csv/724.table
#   inflating: WikiTableQuestions/csv/204-csv/267.tsv
#   inflating: WikiTableQuestions/csv/204-csv/813.csv
#   inflating: WikiTableQuestions/csv/204-csv/609.tsv
#   inflating: WikiTableQuestions/csv/204-csv/175.table
#   inflating: WikiTableQuestions/csv/204-csv/466.html
#   inflating: WikiTableQuestions/csv/204-csv/932.tsv
#   inflating: WikiTableQuestions/csv/204-csv/480.csv
#   inflating: WikiTableQuestions/csv/204-csv/170.csv
#   inflating: WikiTableQuestions/csv/204-csv/123.tsv
#   inflating: WikiTableQuestions/csv/204-csv/348.html
#   inflating: WikiTableQuestions/csv/204-csv/729.csv
#   inflating: WikiTableQuestions/csv/204-csv/258.tsv
#   inflating: WikiTableQuestions/csv/204-csv/740.csv
#   inflating: WikiTableQuestions/csv/204-csv/479.table
#   inflating: WikiTableQuestions/csv/204-csv/602.tsv
#   inflating: WikiTableQuestions/csv/204-csv/246.tsv
#   inflating: WikiTableQuestions/csv/204-csv/526.table
#   inflating: WikiTableQuestions/csv/204-csv/450.table
#   inflating: WikiTableQuestions/csv/204-csv/37.csv
#   inflating: WikiTableQuestions/csv/204-csv/430.tsv
#   inflating: WikiTableQuestions/csv/204-csv/184.tsv
#   inflating: WikiTableQuestions/csv/204-csv/472.table
#   inflating: WikiTableQuestions/csv/204-csv/487.csv
#   inflating: WikiTableQuestions/csv/204-csv/341.table
#   inflating: WikiTableQuestions/csv/204-csv/503.html
#   inflating: WikiTableQuestions/csv/204-csv/490.tsv
#   inflating: WikiTableQuestions/csv/204-csv/32.csv
#   inflating: WikiTableQuestions/csv/204-csv/327.tsv
#   inflating: WikiTableQuestions/csv/204-csv/465.csv
#   inflating: WikiTableQuestions/csv/204-csv/897.html
#   inflating: WikiTableQuestions/csv/204-csv/179.tsv
#   inflating: WikiTableQuestions/csv/204-csv/617.table
#   inflating: WikiTableQuestions/csv/204-csv/882.csv
#   inflating: WikiTableQuestions/csv/204-csv/370.table
#   inflating: WikiTableQuestions/csv/204-csv/802.tsv
#   inflating: WikiTableQuestions/csv/204-csv/672.csv
#   inflating: WikiTableQuestions/csv/204-csv/126.html
#   inflating: WikiTableQuestions/csv/204-csv/989.table
#   inflating: WikiTableQuestions/csv/204-csv/259.html
#   inflating: WikiTableQuestions/csv/204-csv/832.tsv
#   inflating: WikiTableQuestions/csv/204-csv/690.table
#   inflating: WikiTableQuestions/csv/204-csv/531.html
#   inflating: WikiTableQuestions/csv/204-csv/262.html
#   inflating: WikiTableQuestions/csv/204-csv/794.table
#   inflating: WikiTableQuestions/csv/204-csv/300.html
#   inflating: WikiTableQuestions/csv/204-csv/574.html
#   inflating: WikiTableQuestions/csv/204-csv/445.html
#   inflating: WikiTableQuestions/csv/204-csv/589.html
#   inflating: WikiTableQuestions/csv/204-csv/582.table
#   inflating: WikiTableQuestions/csv/204-csv/228.html
#   inflating: WikiTableQuestions/csv/204-csv/870.table
#   inflating: WikiTableQuestions/csv/204-csv/483.html
#   inflating: WikiTableQuestions/csv/204-csv/788.csv
#   inflating: WikiTableQuestions/csv/204-csv/22.table
#   inflating: WikiTableQuestions/csv/204-csv/174.html
#   inflating: WikiTableQuestions/csv/204-csv/493.tsv
#   inflating: WikiTableQuestions/csv/204-csv/300.tsv
#   inflating: WikiTableQuestions/csv/204-csv/116.tsv
#   inflating: WikiTableQuestions/csv/204-csv/957.tsv
#   inflating: WikiTableQuestions/csv/204-csv/557.table
#   inflating: WikiTableQuestions/csv/204-csv/747.csv
#   inflating: WikiTableQuestions/csv/204-csv/314.tsv
#   inflating: WikiTableQuestions/csv/204-csv/902.html
#   inflating: WikiTableQuestions/csv/204-csv/190.html
#   inflating: WikiTableQuestions/csv/204-csv/873.csv
#   inflating: WikiTableQuestions/csv/204-csv/403.tsv
#   inflating: WikiTableQuestions/csv/204-csv/486.tsv
#   inflating: WikiTableQuestions/csv/204-csv/568.html
#   inflating: WikiTableQuestions/csv/204-csv/344.csv
#   inflating: WikiTableQuestions/csv/204-csv/447.csv
#   inflating: WikiTableQuestions/csv/204-csv/187.csv
#   inflating: WikiTableQuestions/csv/204-csv/40.csv
#   inflating: WikiTableQuestions/csv/204-csv/336.tsv
#   inflating: WikiTableQuestions/csv/204-csv/309.table
#   inflating: WikiTableQuestions/csv/204-csv/664.csv
#   inflating: WikiTableQuestions/csv/204-csv/892.html
#   inflating: WikiTableQuestions/csv/204-csv/270.tsv
#   inflating: WikiTableQuestions/csv/204-csv/110.tsv
#   inflating: WikiTableQuestions/csv/204-csv/721.table
#   inflating: WikiTableQuestions/csv/204-csv/961.html
#   inflating: WikiTableQuestions/csv/204-csv/148.tsv
#   inflating: WikiTableQuestions/csv/204-csv/559.tsv
#   inflating: WikiTableQuestions/csv/204-csv/779.html
#   inflating: WikiTableQuestions/csv/204-csv/31.html
#   inflating: WikiTableQuestions/csv/204-csv/925.table
#   inflating: WikiTableQuestions/csv/204-csv/769.table
#   inflating: WikiTableQuestions/csv/204-csv/390.tsv
#   inflating: WikiTableQuestions/csv/204-csv/566.tsv
#   inflating: WikiTableQuestions/csv/204-csv/397.html
#   inflating: WikiTableQuestions/csv/204-csv/241.csv
#   inflating: WikiTableQuestions/csv/204-csv/128.csv
#   inflating: WikiTableQuestions/csv/204-csv/970.table
#   inflating: WikiTableQuestions/csv/204-csv/292.table
#   inflating: WikiTableQuestions/csv/204-csv/567.csv
#   inflating: WikiTableQuestions/csv/204-csv/551.tsv
#   inflating: WikiTableQuestions/csv/204-csv/656.tsv
#   inflating: WikiTableQuestions/csv/204-csv/12.tsv
#   inflating: WikiTableQuestions/csv/204-csv/956.table
#   inflating: WikiTableQuestions/csv/204-csv/903.table
#   inflating: WikiTableQuestions/csv/204-csv/524.table
#   inflating: WikiTableQuestions/csv/204-csv/683.table
#   inflating: WikiTableQuestions/csv/204-csv/70.csv
#   inflating: WikiTableQuestions/csv/204-csv/236.table
#   inflating: WikiTableQuestions/csv/204-csv/734.tsv
#   inflating: WikiTableQuestions/csv/204-csv/396.tsv
#   inflating: WikiTableQuestions/csv/204-csv/863.table
#   inflating: WikiTableQuestions/csv/204-csv/510.tsv
#   inflating: WikiTableQuestions/csv/204-csv/14.tsv
#   inflating: WikiTableQuestions/csv/204-csv/424.tsv
#   inflating: WikiTableQuestions/csv/204-csv/807.table
#   inflating: WikiTableQuestions/csv/204-csv/68.tsv
#   inflating: WikiTableQuestions/csv/204-csv/643.table
#   inflating: WikiTableQuestions/csv/204-csv/773.table
#   inflating: WikiTableQuestions/csv/204-csv/754.csv
#   inflating: WikiTableQuestions/csv/204-csv/754.tsv
#   inflating: WikiTableQuestions/csv/204-csv/617.html
#   inflating: WikiTableQuestions/csv/204-csv/103.tsv
#   inflating: WikiTableQuestions/csv/204-csv/429.html
#   inflating: WikiTableQuestions/csv/204-csv/556.tsv
#   inflating: WikiTableQuestions/csv/204-csv/921.tsv
#   inflating: WikiTableQuestions/csv/204-csv/540.html
#   inflating: WikiTableQuestions/csv/204-csv/217.table
#   inflating: WikiTableQuestions/csv/204-csv/90.html
#   inflating: WikiTableQuestions/csv/204-csv/649.table
#   inflating: WikiTableQuestions/csv/204-csv/873.tsv
#   inflating: WikiTableQuestions/csv/204-csv/974.tsv
#   inflating: WikiTableQuestions/csv/204-csv/333.tsv
#   inflating: WikiTableQuestions/csv/204-csv/427.csv
#   inflating: WikiTableQuestions/csv/204-csv/288.html
#   inflating: WikiTableQuestions/csv/204-csv/680.html
#   inflating: WikiTableQuestions/csv/204-csv/140.html
#   inflating: WikiTableQuestions/csv/204-csv/482.html
#   inflating: WikiTableQuestions/csv/204-csv/27.csv
#   inflating: WikiTableQuestions/csv/204-csv/494.table
#   inflating: WikiTableQuestions/csv/204-csv/142.table
#   inflating: WikiTableQuestions/csv/204-csv/709.tsv
#   inflating: WikiTableQuestions/csv/204-csv/990.tsv
#   inflating: WikiTableQuestions/csv/204-csv/535.html
#   inflating: WikiTableQuestions/csv/204-csv/343.tsv
#   inflating: WikiTableQuestions/csv/204-csv/521.tsv
#   inflating: WikiTableQuestions/csv/204-csv/256.tsv
#   inflating: WikiTableQuestions/csv/204-csv/365.csv
#   inflating: WikiTableQuestions/csv/204-csv/218.csv
#   inflating: WikiTableQuestions/csv/204-csv/964.table
#   inflating: WikiTableQuestions/csv/204-csv/713.html
#   inflating: WikiTableQuestions/csv/204-csv/827.tsv
#   inflating: WikiTableQuestions/csv/204-csv/741.table
#   inflating: WikiTableQuestions/csv/204-csv/981.table
#   inflating: WikiTableQuestions/csv/204-csv/486.html
#   inflating: WikiTableQuestions/csv/204-csv/310.tsv
#   inflating: WikiTableQuestions/csv/204-csv/36.html
#   inflating: WikiTableQuestions/csv/204-csv/311.html
#   inflating: WikiTableQuestions/csv/204-csv/635.table
#   inflating: WikiTableQuestions/csv/204-csv/112.csv
#   inflating: WikiTableQuestions/csv/204-csv/390.html
#   inflating: WikiTableQuestions/csv/204-csv/339.html
#   inflating: WikiTableQuestions/csv/204-csv/30.tsv
#   inflating: WikiTableQuestions/csv/204-csv/632.tsv
#   inflating: WikiTableQuestions/csv/204-csv/180.table
#   inflating: WikiTableQuestions/csv/204-csv/265.tsv
#   inflating: WikiTableQuestions/csv/204-csv/661.html
#   inflating: WikiTableQuestions/csv/204-csv/999.html
#   inflating: WikiTableQuestions/csv/204-csv/52.table
#   inflating: WikiTableQuestions/csv/204-csv/31.csv
#   inflating: WikiTableQuestions/csv/204-csv/189.html
#   inflating: WikiTableQuestions/csv/204-csv/129.csv
#   inflating: WikiTableQuestions/csv/204-csv/194.tsv
#   inflating: WikiTableQuestions/csv/204-csv/938.table
#   inflating: WikiTableQuestions/csv/204-csv/770.html
#   inflating: WikiTableQuestions/csv/204-csv/456.table
#   inflating: WikiTableQuestions/csv/204-csv/34.html
#   inflating: WikiTableQuestions/csv/204-csv/39.tsv
#   inflating: WikiTableQuestions/csv/204-csv/868.html
#   inflating: WikiTableQuestions/csv/204-csv/552.csv
#   inflating: WikiTableQuestions/csv/204-csv/374.tsv
#   inflating: WikiTableQuestions/csv/204-csv/855.tsv
#   inflating: WikiTableQuestions/csv/204-csv/313.table
#   inflating: WikiTableQuestions/csv/204-csv/136.html
#   inflating: WikiTableQuestions/csv/204-csv/625.csv
#   inflating: WikiTableQuestions/csv/204-csv/286.table
#   inflating: WikiTableQuestions/csv/204-csv/278.tsv
#   inflating: WikiTableQuestions/csv/204-csv/424.html
#   inflating: WikiTableQuestions/csv/204-csv/918.html
#   inflating: WikiTableQuestions/csv/204-csv/221.tsv
#   inflating: WikiTableQuestions/csv/204-csv/249.html
#   inflating: WikiTableQuestions/csv/204-csv/575.csv
#   inflating: WikiTableQuestions/csv/204-csv/603.table
#   inflating: WikiTableQuestions/csv/204-csv/867.tsv
#   inflating: WikiTableQuestions/csv/204-csv/920.csv
#   inflating: WikiTableQuestions/csv/204-csv/173.csv
#   inflating: WikiTableQuestions/csv/204-csv/471.table
#   inflating: WikiTableQuestions/csv/204-csv/199.tsv
#   inflating: WikiTableQuestions/csv/204-csv/525.csv
#   inflating: WikiTableQuestions/csv/204-csv/712.csv
#   inflating: WikiTableQuestions/csv/204-csv/780.tsv
#   inflating: WikiTableQuestions/csv/204-csv/383.table
#   inflating: WikiTableQuestions/csv/204-csv/191.table
#   inflating: WikiTableQuestions/csv/204-csv/586.csv
#   inflating: WikiTableQuestions/csv/204-csv/346.tsv
#   inflating: WikiTableQuestions/csv/204-csv/181.html
#   inflating: WikiTableQuestions/csv/204-csv/234.tsv
#   inflating: WikiTableQuestions/csv/204-csv/100.html
#   inflating: WikiTableQuestions/csv/204-csv/924.table
#   inflating: WikiTableQuestions/csv/204-csv/692.tsv
#   inflating: WikiTableQuestions/csv/204-csv/441.csv
#   inflating: WikiTableQuestions/csv/204-csv/523.table
#   inflating: WikiTableQuestions/csv/204-csv/526.csv
#   inflating: WikiTableQuestions/csv/204-csv/890.table
#   inflating: WikiTableQuestions/csv/204-csv/906.csv
#   inflating: WikiTableQuestions/csv/204-csv/78.csv
#   inflating: WikiTableQuestions/csv/204-csv/406.tsv
#   inflating: WikiTableQuestions/csv/204-csv/481.html
#   inflating: WikiTableQuestions/csv/204-csv/601.tsv
#   inflating: WikiTableQuestions/csv/204-csv/490.csv
#   inflating: WikiTableQuestions/csv/204-csv/177.html
#   inflating: WikiTableQuestions/csv/204-csv/955.tsv
#   inflating: WikiTableQuestions/csv/204-csv/985.html
#   inflating: WikiTableQuestions/csv/204-csv/508.html
#   inflating: WikiTableQuestions/csv/204-csv/829.html
#   inflating: WikiTableQuestions/csv/204-csv/582.tsv
#   inflating: WikiTableQuestions/csv/204-csv/79.csv
#   inflating: WikiTableQuestions/csv/204-csv/217.csv
#   inflating: WikiTableQuestions/csv/204-csv/423.csv
#   inflating: WikiTableQuestions/csv/204-csv/545.html
#   inflating: WikiTableQuestions/csv/204-csv/13.html
#   inflating: WikiTableQuestions/csv/204-csv/714.tsv
#   inflating: WikiTableQuestions/csv/204-csv/82.html
#   inflating: WikiTableQuestions/csv/204-csv/462.csv
#   inflating: WikiTableQuestions/csv/204-csv/97.html
#   inflating: WikiTableQuestions/csv/204-csv/921.html
#   inflating: WikiTableQuestions/csv/204-csv/398.table
#   inflating: WikiTableQuestions/csv/204-csv/158.csv
#   inflating: WikiTableQuestions/csv/204-csv/844.table
#   inflating: WikiTableQuestions/csv/204-csv/359.csv
#   inflating: WikiTableQuestions/csv/204-csv/145.table
#   inflating: WikiTableQuestions/csv/204-csv/353.tsv
#   inflating: WikiTableQuestions/csv/204-csv/59.tsv
#   inflating: WikiTableQuestions/csv/204-csv/574.table
#   inflating: WikiTableQuestions/csv/204-csv/56.table
#   inflating: WikiTableQuestions/csv/204-csv/553.html
#   inflating: WikiTableQuestions/csv/204-csv/550.html
#   inflating: WikiTableQuestions/csv/204-csv/24.html
#   inflating: WikiTableQuestions/csv/204-csv/38.tsv
#   inflating: WikiTableQuestions/csv/204-csv/860.tsv
#   inflating: WikiTableQuestions/csv/204-csv/347.table
#   inflating: WikiTableQuestions/csv/204-csv/162.csv
#   inflating: WikiTableQuestions/csv/204-csv/452.html
#   inflating: WikiTableQuestions/csv/204-csv/15.table
#   inflating: WikiTableQuestions/csv/204-csv/260.table
#   inflating: WikiTableQuestions/csv/204-csv/438.tsv
#   inflating: WikiTableQuestions/csv/204-csv/148.table
#   inflating: WikiTableQuestions/csv/204-csv/375.table
#   inflating: WikiTableQuestions/csv/204-csv/664.table
#   inflating: WikiTableQuestions/csv/204-csv/105.csv
#   inflating: WikiTableQuestions/csv/204-csv/572.table
#   inflating: WikiTableQuestions/csv/204-csv/542.html
#   inflating: WikiTableQuestions/csv/204-csv/384.table
#   inflating: WikiTableQuestions/csv/204-csv/698.tsv
#   inflating: WikiTableQuestions/csv/204-csv/965.table
#   inflating: WikiTableQuestions/csv/204-csv/981.html
#   inflating: WikiTableQuestions/csv/204-csv/611.table
#   inflating: WikiTableQuestions/csv/204-csv/69.csv
#   inflating: WikiTableQuestions/csv/204-csv/29.tsv
#   inflating: WikiTableQuestions/csv/204-csv/4.table
#   inflating: WikiTableQuestions/csv/204-csv/592.tsv
#   inflating: WikiTableQuestions/csv/204-csv/497.html
#   inflating: WikiTableQuestions/csv/204-csv/142.csv
#   inflating: WikiTableQuestions/csv/204-csv/431.html
#   inflating: WikiTableQuestions/csv/204-csv/240.csv
#   inflating: WikiTableQuestions/csv/204-csv/839.table
#   inflating: WikiTableQuestions/csv/204-csv/653.table
#   inflating: WikiTableQuestions/csv/204-csv/252.html
#   inflating: WikiTableQuestions/csv/204-csv/912.tsv
#   inflating: WikiTableQuestions/csv/204-csv/667.html
#   inflating: WikiTableQuestions/csv/204-csv/35.csv
#   inflating: WikiTableQuestions/csv/204-csv/815.table
#   inflating: WikiTableQuestions/csv/204-csv/521.html
#   inflating: WikiTableQuestions/csv/204-csv/0.table
#   inflating: WikiTableQuestions/csv/204-csv/551.csv
#   inflating: WikiTableQuestions/csv/204-csv/399.html
#   inflating: WikiTableQuestions/csv/204-csv/234.html
#   inflating: WikiTableQuestions/csv/204-csv/867.table
#   inflating: WikiTableQuestions/csv/204-csv/157.table
#   inflating: WikiTableQuestions/csv/204-csv/724.csv
#   inflating: WikiTableQuestions/csv/204-csv/430.table
#   inflating: WikiTableQuestions/csv/204-csv/332.html
#   inflating: WikiTableQuestions/csv/204-csv/613.csv
#   inflating: WikiTableQuestions/csv/204-csv/21.html
#   inflating: WikiTableQuestions/csv/204-csv/882.tsv
#   inflating: WikiTableQuestions/csv/204-csv/788.table
#   inflating: WikiTableQuestions/csv/204-csv/400.html
#   inflating: WikiTableQuestions/csv/204-csv/735.csv
#   inflating: WikiTableQuestions/csv/204-csv/501.tsv
#   inflating: WikiTableQuestions/csv/204-csv/909.html
#   inflating: WikiTableQuestions/csv/204-csv/441.tsv
#   inflating: WikiTableQuestions/csv/204-csv/767.table
#   inflating: WikiTableQuestions/csv/204-csv/197.table
#   inflating: WikiTableQuestions/csv/204-csv/641.tsv
#   inflating: WikiTableQuestions/csv/204-csv/777.csv
#   inflating: WikiTableQuestions/csv/204-csv/610.table
#   inflating: WikiTableQuestions/csv/204-csv/296.csv
#   inflating: WikiTableQuestions/csv/204-csv/601.csv
#   inflating: WikiTableQuestions/csv/204-csv/984.csv
#   inflating: WikiTableQuestions/csv/204-csv/314.html
#   inflating: WikiTableQuestions/csv/204-csv/291.csv
#   inflating: WikiTableQuestions/csv/204-csv/492.table
#   inflating: WikiTableQuestions/csv/204-csv/815.html
#   inflating: WikiTableQuestions/csv/204-csv/247.table
#   inflating: WikiTableQuestions/csv/204-csv/919.tsv
#   inflating: WikiTableQuestions/csv/204-csv/472.html
#   inflating: WikiTableQuestions/csv/204-csv/113.csv
#   inflating: WikiTableQuestions/csv/204-csv/192.tsv
#   inflating: WikiTableQuestions/csv/204-csv/941.csv
#   inflating: WikiTableQuestions/csv/204-csv/20.csv
#   inflating: WikiTableQuestions/csv/204-csv/883.csv
#   inflating: WikiTableQuestions/csv/204-csv/680.csv
#   inflating: WikiTableQuestions/csv/204-csv/373.table
#   inflating: WikiTableQuestions/csv/204-csv/43.tsv
#   inflating: WikiTableQuestions/csv/204-csv/660.csv
#   inflating: WikiTableQuestions/csv/204-csv/662.tsv
#   inflating: WikiTableQuestions/csv/204-csv/636.table
#   inflating: WikiTableQuestions/csv/204-csv/608.tsv
#   inflating: WikiTableQuestions/csv/204-csv/274.table
#   inflating: WikiTableQuestions/csv/204-csv/978.table
#   inflating: WikiTableQuestions/csv/204-csv/100.csv
tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/129.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/185.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/138.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/805.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/909.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/878.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/590.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/67.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/810.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/946.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/658.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/890.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/933.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/114.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/126.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/155.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/795.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/694.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/691.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/38.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/678.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/218.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/816.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/952.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/390.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/532.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/393.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/555.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/211.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/873.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/286.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/767.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/360.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/103.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/845.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/717.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/877.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/776.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/601.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/170.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/846.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/942.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/875.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/951.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/61.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/477.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/932.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/154.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/962.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/748.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/174.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/736.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/947.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/501.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/44.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/413.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/52.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/839.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/166.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/834.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/704.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/7.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/884.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/239.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/356.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/245.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/323.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/950.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/714.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/869.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/758.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/855.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/785.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/343.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/440.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/236.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/53.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/33.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/407.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/639.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/480.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/587.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/433.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/243.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/256.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/798.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/157.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/387.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/337.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/637.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/505.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/899.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/669.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/868.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/100.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/234.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/537.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/831.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/627.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/3.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/332.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/840.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/66.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/58.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/213.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/119.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/175.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/26.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/519.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/526.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/686.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/953.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/720.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/990.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/128.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/851.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/567.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/9.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/550.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/132.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/616.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/861.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/426.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/284.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/299.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/688.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/891.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/493.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/328.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/576.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/240.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/588.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/151.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/647.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/762.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/982.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/849.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/993.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/735.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/163.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/579.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/871.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/675.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/515.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/926.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/106.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/266.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/832.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/572.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/0.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/118.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/611.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/482.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/981.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/683.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/823.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/644.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/84.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/453.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/466.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/182.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/808.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/192.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/954.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/105.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/661.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/898.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/589.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/405.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/525.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/958.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/574.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/726.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/562.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/595.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/264.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/922.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/134.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/521.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/710.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/275.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/804.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/636.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/570.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/434.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/252.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/335.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/569.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/77.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/352.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/571.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/967.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/784.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/793.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/754.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/463.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/116.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/924.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/972.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/318.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/402.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/744.tagged
#   inflating: WikiTableQuestions/tagged/204-tagged/690.tagged
#    creating: WikiTableQuestions/tagged/201-tagged/
#   inflating: WikiTableQuestions/tagged/201-tagged/24.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/47.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/27.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/25.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/40.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/20.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/19.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/1.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/46.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/22.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/36.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/31.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/45.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/15.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/8.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/29.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/18.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/13.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/21.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/43.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/10.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/11.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/2.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/4.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/39.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/49.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/23.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/35.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/42.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/14.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/48.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/37.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/5.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/17.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/6.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/30.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/28.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/34.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/38.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/44.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/7.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/33.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/3.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/26.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/9.tagged
#   inflating: WikiTableQuestions/tagged/201-tagged/0.tagged
#    creating: WikiTableQuestions/tagged/data/
#   inflating: WikiTableQuestions/tagged/data/training.tagged
#   inflating: WikiTableQuestions/tagged/data/pristine-seen-tables.tagged
#   inflating: WikiTableQuestions/tagged/data/pristine-unseen-tables.tagged

# %%
import pandas as pd
from pathlib import Path

data_dir = Path("./WikiTableQuestions/csv/200-csv")
csv_files = sorted([f for f in data_dir.glob("*.csv")])
dfs = []
for csv_file in csv_files:
    print(f"processing file: {csv_file}")
    try:
        df = pd.read_csv(csv_file)
        dfs.append(df)
    except Exception as e:
        print(f"Error parsing {csv_file}: {str(e)}")
# Out:
# processing file: WikiTableQuestions/csv/200-csv/0.csv
# processing file: WikiTableQuestions/csv/200-csv/1.csv
# processing file: WikiTableQuestions/csv/200-csv/10.csv
# processing file: WikiTableQuestions/csv/200-csv/11.csv
# processing file: WikiTableQuestions/csv/200-csv/12.csv
# processing file: WikiTableQuestions/csv/200-csv/14.csv
# processing file: WikiTableQuestions/csv/200-csv/15.csv
# Error parsing WikiTableQuestions/csv/200-csv/15.csv: Error tokenizing data. C error: Expected 4 fields in line 16, saw 5
#
# processing file: WikiTableQuestions/csv/200-csv/17.csv
# Error parsing WikiTableQuestions/csv/200-csv/17.csv: Error tokenizing data. C error: Expected 6 fields in line 5, saw 7
#
# processing file: WikiTableQuestions/csv/200-csv/18.csv
# processing file: WikiTableQuestions/csv/200-csv/20.csv
# processing file: WikiTableQuestions/csv/200-csv/22.csv
# processing file: WikiTableQuestions/csv/200-csv/24.csv
# processing file: WikiTableQuestions/csv/200-csv/25.csv
# processing file: WikiTableQuestions/csv/200-csv/26.csv
# processing file: WikiTableQuestions/csv/200-csv/28.csv
# processing file: WikiTableQuestions/csv/200-csv/29.csv
# processing file: WikiTableQuestions/csv/200-csv/3.csv
# processing file: WikiTableQuestions/csv/200-csv/30.csv
# processing file: WikiTableQuestions/csv/200-csv/31.csv
# processing file: WikiTableQuestions/csv/200-csv/32.csv
# processing file: WikiTableQuestions/csv/200-csv/33.csv
# processing file: WikiTableQuestions/csv/200-csv/34.csv
# Error parsing WikiTableQuestions/csv/200-csv/34.csv: Error tokenizing data. C error: Expected 4 fields in line 6, saw 13
#
# processing file: WikiTableQuestions/csv/200-csv/35.csv
# processing file: WikiTableQuestions/csv/200-csv/36.csv
# processing file: WikiTableQuestions/csv/200-csv/37.csv
# processing file: WikiTableQuestions/csv/200-csv/38.csv
# processing file: WikiTableQuestions/csv/200-csv/4.csv
# processing file: WikiTableQuestions/csv/200-csv/41.csv
# processing file: WikiTableQuestions/csv/200-csv/42.csv
# processing file: WikiTableQuestions/csv/200-csv/44.csv
# processing file: WikiTableQuestions/csv/200-csv/45.csv
# processing file: WikiTableQuestions/csv/200-csv/46.csv
# processing file: WikiTableQuestions/csv/200-csv/47.csv
# processing file: WikiTableQuestions/csv/200-csv/48.csv
# processing file: WikiTableQuestions/csv/200-csv/7.csv
# processing file: WikiTableQuestions/csv/200-csv/8.csv
# processing file: WikiTableQuestions/csv/200-csv/9.csv

# %% [markdown]
# ### Extract Table Name and Summary from each Table
#
# Here we use gpt-4o-mini to extract a table name (with underscores) and summary from each table with our Pydantic program.

# %%
tableinfo_dir = "WikiTableQuestions_TableInfo"
# !mkdir {tableinfo_dir}

# %%
from llama_index.core.prompts import ChatPromptTemplate
from llama_index.core.bridge.pydantic import BaseModel, Field
from llama_index.core.llms import ChatMessage


class TableInfo(BaseModel):
    """Information regarding a structured table."""

    table_name: str = Field(
        ..., description="table name (must be underscores and NO spaces)"
    )
    table_summary: str = Field(
        ..., description="short, concise summary/caption of the table"
    )


prompt_str = """\
Give me a summary of the table with the following JSON format.

- The table name must be unique to the table and describe it while being concise.
- Do NOT output a generic table name (e.g. table, my_table).

Do NOT make the table name one of the following: {exclude_table_name_list}

Table:
{table_str}

Summary: """
prompt_tmpl = ChatPromptTemplate(
    message_templates=[ChatMessage.from_str(prompt_str, role="user")]
)

# %%
import json


def _get_tableinfo_with_index(idx: int) -> str:
    results_gen = Path(tableinfo_dir).glob(f"{idx}_*")
    results_list = list(results_gen)
    if len(results_list) == 0:
        return None
    elif len(results_list) == 1:
        path = results_list[0]
        return TableInfo.parse_file(path)
    else:
        raise ValueError(
            f"More than one file matching index: {list(results_gen)}"
        )


table_names = set()
table_infos = []
for idx, df in enumerate(dfs):
    table_info = _get_tableinfo_with_index(idx)
    if table_info:
        table_infos.append(table_info)
    else:
        while True:
            df_str = df.head(10).to_csv()
            llm = Settings.llm
            table_info = llm.structured_predict(
                TableInfo,
                prompt_tmpl,
                table_str=df_str,
                exclude_table_name_list=str(list(table_names)),
            )
            table_name = table_info.table_name
            print(f"Processed table: {table_name}")
            if table_name not in table_names:
                table_names.add(table_name)
                break
            else:
                # try again
                print(f"Table name {table_name} already exists, trying again.")
                pass

        out_file = f"{tableinfo_dir}/{idx}_{table_name}.json"
        json.dump(table_info.dict(), open(out_file, "w"))
    table_infos.append(table_info)
# Out:
# Processed table: AlbumChartPositions
# Processed table: FilmTitlesAndPerformances
# Processed table: TrafficAccidentStats
# Processed table: AwardsNomineesResults
# Processed table: TheatreAwardsNominees
# Processed table: BadBoyAlbums
# Processed table: RadioStationFrequencyInfo
# Processed table: MissingPersonsIncidents
# Processed table: MusicChartPositions
# Processed table: KodachromeFilmHistory
# Processed table: BBC_Radio_Financials
# Processed table: AirfieldLocationInfo
# Processed table: VoterPartyBreakdown
# Processed table: ClubPerformanceStats
# Processed table: HorseRaceWinners
# Processed table: GrammyAwardsNominees
# Processed table: BoxingMatchResults
# Processed table: FootballSeasonResults
# Processed table: DistrictPopulationDensity
# Processed table: VoterPartyBreakdown
# Table name VoterPartyBreakdown already exists, trying again.
# Processed table: VoterBreakdownByParty
# Processed table: AcademyAwardActressNominations
# Processed table: MPOfficeSuccessions
# Processed table: MunicipalityBoundaryChanges
# Processed table: FIFA_World_Cup_Group_Stage_Results
# Processed table: ProbabilityEncodingTable
# Processed table: MonthlyClimateStats
# Processed table: LocalGovernmentLeadershipTerms
# Processed table: NM_ExecutiveOfficerList
# Processed table: MonthlyClimateStats
# Table name MonthlyClimateStats already exists, trying again.
# Processed table: MonthlyClimateStats
# Table name MonthlyClimateStats already exists, trying again.
# Processed table: MonthlyClimateStats
# Table name MonthlyClimateStats already exists, trying again.
# Processed table: MonthlyClimateStats
# Table name MonthlyClimateStats already exists, trying again.
# Processed table: MonthlyClimateStats
# Table name MonthlyClimateStats already exists, trying again.
# Processed table: MonthlyClimateStats
# Table name MonthlyClimateStats already exists, trying again.
# Processed table: MonthlyClimateStats
# Table name MonthlyClimateStats already exists, trying again.
# Processed table: MonthlyClimateStats
# Table name MonthlyClimateStats already exists, trying again.
# Processed table: MonthlyClimateStats
# Table name MonthlyClimateStats already exists, trying again.
# Processed table: MonthlyClimateStats
# Table name MonthlyClimateStats already exists, trying again.
# Processed table: MonthlyClimateStats
# Table name MonthlyClimateStats already exists, trying again.
# Processed table: MonthlyClimateStats
# Table name MonthlyClimateStats already exists, trying again.
# Processed table: MonthlyClimateStats
# Table name MonthlyClimateStats already exists, trying again.
# Processed table: MonthlyClimateStats
# Table name MonthlyClimateStats already exists, trying again.
# Processed table: MonthlyClimateStats
# Table name MonthlyClimateStats already exists, trying again.
# Processed table: MonthlyClimateStats
# Table name MonthlyClimateStats already exists, trying again.
# Processed table: MonthlyClimateStats
# Table name MonthlyClimateStats already exists, trying again.
# Processed table: ClimateMonthlyAverages
# Processed table: ExperimentTimeline
# Processed table: MonthlyClimateStats
# Table name MonthlyClimateStats already exists, trying again.
# Processed table: MonthlyWeatherStats
# Processed table: LanguagePhrases
# Processed table: SchoolDistrictInfo
# Processed table: Cancer_Gene_Functions

# %% [markdown]
# ### Put Data in SQL Database
#
# We use `sqlalchemy`, a popular SQL database toolkit, to load all the tables.

# %%
# put data into sqlite db
from sqlalchemy import (
    create_engine,
    MetaData,
    Table,
    Column,
    String,
    Integer,
)
import re


# Function to create a sanitized column name
def sanitize_column_name(col_name):
    # Remove special characters and replace spaces with underscores
    return re.sub(r"\W+", "_", col_name)


# Function to create a table from a DataFrame using SQLAlchemy
def create_table_from_dataframe(
    df: pd.DataFrame, table_name: str, engine, metadata_obj
):
    # Sanitize column names
    sanitized_columns = {col: sanitize_column_name(col) for col in df.columns}
    df = df.rename(columns=sanitized_columns)

    # Dynamically create columns based on DataFrame columns and data types
    columns = [
        Column(col, String if dtype == "object" else Integer)
        for col, dtype in zip(df.columns, df.dtypes)
    ]

    # Create a table with the defined columns
    table = Table(table_name, metadata_obj, *columns)

    # Create the table in the database
    metadata_obj.create_all(engine)

    # Insert data from DataFrame into the table
    with engine.connect() as conn:
        for _, row in df.iterrows():
            insert_stmt = table.insert().values(**row.to_dict())
            conn.execute(insert_stmt)
        conn.commit()


# engine = create_engine("sqlite:///:memory:")
engine = create_engine("sqlite:///wiki_table_questions.db")
metadata_obj = MetaData()
for idx, df in enumerate(dfs):
    tableinfo = _get_tableinfo_with_index(idx)
    print(f"Creating table: {tableinfo.table_name}")
    create_table_from_dataframe(df, tableinfo.table_name, engine, metadata_obj)
# Out:
# Creating table: AlbumChartPositions
# Creating table: FilmTitlesAndPerformances
# Creating table: TrafficAccidentStats
# Creating table: AwardsNomineesResults
# Creating table: TheatreAwardsNominees
# Creating table: BadBoyAlbums
# Creating table: RadioStationFrequencyInfo
# Creating table: MissingPersonsIncidents
# Creating table: MusicChartPositions
# Creating table: KodachromeFilmHistory
# Creating table: BBC_Radio_Financials
# Creating table: AirfieldLocationInfo
# Creating table: VoterPartyBreakdown
# Creating table: ClubPerformanceStats
# Creating table: HorseRaceWinners
# Creating table: GrammyAwardsNominees
# Creating table: BoxingMatchResults
# Creating table: FootballSeasonResults
# Creating table: DistrictPopulationDensity
# Creating table: VoterBreakdownByParty
# Creating table: AcademyAwardActressNominations
# Creating table: MPOfficeSuccessions
# Creating table: MunicipalityBoundaryChanges
# Creating table: FIFA_World_Cup_Group_Stage_Results
# Creating table: ProbabilityEncodingTable
# Creating table: MonthlyClimateStats
# Creating table: LocalGovernmentLeadershipTerms
# Creating table: NM_ExecutiveOfficerList
# Creating table: ClimateMonthlyAverages
# Creating table: ExperimentTimeline
# Creating table: MonthlyWeatherStats
# Creating table: LanguagePhrases
# Creating table: SchoolDistrictInfo
# Creating table: Cancer_Gene_Functions

# %%
# # setup Arize Phoenix for logging/observability
# import phoenix as px
# import llama_index.core

# px.launch_app()
# llama_index.core.set_global_handler("arize_phoenix")

# %% [markdown]
# ## Advanced Capability 1: Text-to-SQL with Query-Time Table Retrieval.
#
# We now show you how to setup an e2e text-to-SQL with table retrieval.
#
# ### Define Modules
#
# Here we define the core modules.
# 1. Object index + retriever to store table schemas
# 2. SQLDatabase object to connect to the above tables + SQLRetriever.
# 3. Text-to-SQL Prompt
# 4. Response synthesis Prompt
# 5. LLM

# %% [markdown]
# Object index, retriever, SQLDatabase

# %%
from llama_index.core.objects import (
    SQLTableNodeMapping,
    ObjectIndex,
    SQLTableSchema,
)
from llama_index.core import SQLDatabase, VectorStoreIndex

sql_database = SQLDatabase(engine)

table_node_mapping = SQLTableNodeMapping(sql_database)
table_schema_objs = [
    SQLTableSchema(table_name=t.table_name, context_str=t.table_summary)
    for t in table_infos
]  # add a SQLTableSchema for each table

obj_index = ObjectIndex.from_objects(
    table_schema_objs,
    table_node_mapping,
    VectorStoreIndex,
)
obj_retriever = obj_index.as_retriever(similarity_top_k=3)

# %% [markdown]
# SQLRetriever + Table Parser

# %%
from llama_index.core.retrievers import SQLRetriever
from typing import List

sql_retriever = SQLRetriever(sql_database)


def get_table_context_str(table_schema_objs: List[SQLTableSchema]):
    """Get table context string."""
    context_strs = []
    for table_schema_obj in table_schema_objs:
        table_info = sql_database.get_single_table_info(
            table_schema_obj.table_name
        )
        if table_schema_obj.context_str:
            table_opt_context = " The table description is: "
            table_opt_context += table_schema_obj.context_str
            table_info += table_opt_context

        context_strs.append(table_info)
    return "\n\n".join(context_strs)

# %% [markdown]
# Text-to-SQL Prompt + Output Parser

# %%
from llama_index.core.prompts.default_prompts import DEFAULT_TEXT_TO_SQL_PROMPT
from llama_index.core import PromptTemplate
from llama_index.core.llms import ChatResponse


def parse_response_to_sql(chat_response: ChatResponse) -> str:
    """Parse response to SQL."""
    response = chat_response.message.content
    sql_query_start = response.find("SQLQuery:")
    if sql_query_start != -1:
        response = response[sql_query_start:]
        # TODO: move to removeprefix after Python 3.9+
        if response.startswith("SQLQuery:"):
            response = response[len("SQLQuery:") :]
    sql_result_start = response.find("SQLResult:")
    if sql_result_start != -1:
        response = response[:sql_result_start]
    return response.strip().strip("```").strip()


text2sql_prompt = DEFAULT_TEXT_TO_SQL_PROMPT.partial_format(
    dialect=engine.dialect.name
)
print(text2sql_prompt.template)
# Out:
# Given an input question, first create a syntactically correct {dialect} query to run, then look at the results of the query and return the answer. You can order the results by a relevant column to return the most interesting examples in the database.
#
# Never query for all the columns from a specific table, only ask for a few relevant columns given the question.
#
# Pay attention to use only the column names that you can see in the schema description. Be careful to not query for columns that do not exist. Pay attention to which column is in which table. Also, qualify column names with the table name when needed. You are required to use the following format, each taking one line:
#
# Question: Question here
# SQLQuery: SQL Query to run
# SQLResult: Result of the SQLQuery
# Answer: Final answer here
#
# Only use tables listed below.
# {schema}
#
# Question: {query_str}
# SQLQuery:

# %% [markdown]
# Response Synthesis Prompt

# %%
response_synthesis_prompt_str = (
    "Given an input question, synthesize a response from the query results.\n"
    "Query: {query_str}\n"
    "SQL: {sql_query}\n"
    "SQL Response: {context_str}\n"
    "Response: "
)
response_synthesis_prompt = PromptTemplate(
    response_synthesis_prompt_str,
)

# %% [markdown]
# ### Define Workflow
#
# Now that the components are in place, let's define the full workflow!

# %%
from llama_index.core.workflow import (
    Workflow,
    StartEvent,
    StopEvent,
    step,
    Context,
    Event,
)


class TableRetrieveEvent(Event):
    """Result of running table retrieval."""

    table_context_str: str
    query: str


class TextToSQLEvent(Event):
    """Text-to-SQL event."""

    sql: str
    query: str


class TextToSQLWorkflow1(Workflow):
    """Text-to-SQL Workflow that does query-time table retrieval."""

    def __init__(
        self,
        obj_retriever,
        text2sql_prompt,
        sql_retriever,
        response_synthesis_prompt,
        llm,
        *args,
        **kwargs
    ) -> None:
        """Init params."""
        super().__init__(*args, **kwargs)
        self.obj_retriever = obj_retriever
        self.text2sql_prompt = text2sql_prompt
        self.sql_retriever = sql_retriever
        self.response_synthesis_prompt = response_synthesis_prompt
        self.llm = Settings.llm

    @step
    def retrieve_tables(
        self, ctx: Context, ev: StartEvent
    ) -> TableRetrieveEvent:
        """Retrieve tables."""
        table_schema_objs = self.obj_retriever.retrieve(ev.query)
        table_context_str = get_table_context_str(table_schema_objs)
        return TableRetrieveEvent(
            table_context_str=table_context_str, query=ev.query
        )

    @step
    def generate_sql(
        self, ctx: Context, ev: TableRetrieveEvent
    ) -> TextToSQLEvent:
        """Generate SQL statement."""
        fmt_messages = self.text2sql_prompt.format_messages(
            query_str=ev.query, schema=ev.table_context_str
        )
        chat_response = self.llm.chat(fmt_messages)
        sql = parse_response_to_sql(chat_response)
        return TextToSQLEvent(sql=sql, query=ev.query)

    @step
    def generate_response(self, ctx: Context, ev: TextToSQLEvent) -> StopEvent:
        """Run SQL retrieval and generate response."""
        retrieved_rows = self.sql_retriever.retrieve(ev.sql)
        fmt_messages = self.response_synthesis_prompt.format_messages(
            sql_query=ev.sql,
            context_str=str(retrieved_rows),
            query_str=ev.query,
        )
        chat_response = llm.chat(fmt_messages)
        return StopEvent(result=chat_response)

# %% [markdown]
# ### Visualize Workflow
#
# A really nice property of workflows is that you can both visualize the execution graph as well as a trace of the most recent execution.

# %%
# !pip install pyvis
# !pip install llama-index-utils-workflow
# Out:
# Requirement already satisfied: pyvis in /usr/local/lib/python3.10/dist-packages (0.3.2)
# Requirement already satisfied: ipython>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from pyvis) (7.34.0)
# Requirement already satisfied: jinja2>=2.9.6 in /usr/local/lib/python3.10/dist-packages (from pyvis) (3.1.4)
# Requirement already satisfied: jsonpickle>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from pyvis) (3.2.2)
# Requirement already satisfied: networkx>=1.11 in /usr/local/lib/python3.10/dist-packages (from pyvis) (3.3)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (71.0.4)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (3.0.47)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9.6->pyvis) (2.1.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=5.3.0->pyvis) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->pyvis) (0.2.13)
# Collecting llama-index-utils-workflow
#   Downloading llama_index_utils_workflow-0.2.1-py3-none-any.whl.metadata (667 bytes)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-utils-workflow) (0.11.7)
# Requirement already satisfied: pyvis<0.4.0,>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from llama-index-utils-workflow) (0.3.2)
# Requirement already satisfied: PyYAML>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (2.0.32)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (3.10.5)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (2024.6.1)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (3.3)
# Requirement already satisfied: nltk>3.8.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (3.9.1)
# Requirement already satisfied: numpy<2.0.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (9.4.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (2.8.2)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (1.16.0)
# Requirement already satisfied: ipython>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (7.34.0)
# Requirement already satisfied: jinja2>=2.9.6 in /usr/local/lib/python3.10/dist-packages (from pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (3.1.4)
# Requirement already satisfied: jsonpickle>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (3.2.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (4.0.3)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (71.0.4)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (3.0.47)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9.6->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (2.1.5)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (2024.5.15)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (3.22.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (1.0.5)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (0.8.4)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (24.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (0.2.13)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-utils-workflow) (1.2.2)
# Downloading llama_index_utils_workflow-0.2.1-py3-none-any.whl (2.6 kB)
# Installing collected packages: llama-index-utils-workflow
# Successfully installed llama-index-utils-workflow-0.2.1

# %%
from llama_index.utils.workflow import draw_all_possible_flows

draw_all_possible_flows(
    TextToSQLWorkflow1, filename="text_to_sql_table_retrieval.html"
)
# Out:
# text_to_sql_table_retrieval.html

# %%
from IPython.display import display, HTML

# Read the contents of the HTML file
with open("text_to_sql_table_retrieval.html", "r") as file:
    html_content = file.read()

# Display the HTML content
display(HTML(html_content))
# Out:
# <html>
#     <head>
#         <meta charset="utf-8">
#
#             <script src="lib/bindings/utils.js"></script>
#             <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/vis-network/9.1.2/dist/dist/vis-network.min.css" integrity="sha512-WgxfT5LWjfszlPHXRmBWHkV2eceiWTOBvrKCNbdgDYTHrT2AeLCGbF4sZlZw3UMN3WtL0tGUoIAKsu8mllg/XA==" crossorigin="anonymous" referrerpolicy="no-referrer" />
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/vis-network/9.1.2/dist/vis-network.min.js" integrity="sha512-LnvoEWDFrqGHlHmDD2101OrLcbsfkrzoSpvtSQtxK3RMnRV0eOkhhBN2dXHKRrUU8p2DGRTk35n4O8nWSVe1mQ==" crossorigin="anonymous" referrerpolicy="no-referrer"></script>
#
#
# <center>
# <h1></h1>
# </center>
#
# <!-- <link rel="stylesheet" href="../node_modules/vis/dist/vis.min.css" type="text/css" />
# <script type="text/javascript" src="../node_modules/vis/dist/vis.js"> </script>-->
#         <link
#           href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta3/dist/css/bootstrap.min.css"
#           rel="stylesheet"
#           integrity="sha384-eOJMYsd53ii+scO/bJGFsiCZc+5NDVN2yr8+0RDqr0Ql0h+rP48ckxlpbzKgwra6"
#           crossorigin="anonymous"
#         />
#         <script
#           src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta3/dist/js/bootstrap.bundle.min.js"
#           integrity="sha384-JEW9xMcG8R+pH31jmWH6WWP0WintQrMb4s7ZOdauHnUtxwoG2vI5DkLtS3qm9Ekf"
#           crossorigin="anonymous"
#         ></script>
#
#
#         <center>
#           <h1></h1>
#         </center>
#         <style type="text/css">
#
#              #mynetwork {
#                  width: 100%;
#                  height: 750px;
#                  background-color: #ffffff;
#                  border: 1px solid lightgray;
#                  position: relative;
#                  float: left;
#              }
#
#
#
#
#
#
#         </style>
#     </head>
#
#
#     <body>
#         <div class="card" style="width: 100%">
#
#
#             <div id="mynetwork" class="card-body"></div>
#         </div>
#
#
#
#
#         <script type="text/javascript">
#
#               // initialize global variables.
#               var edges;
#               var nodes;
#               var allNodes;
#               var allEdges;
#               var nodeColors;
#               var originalNodes;
#               var network;
#               var container;
#               var options, data;
#               var filter = {
#                   item : '',
#                   property : '',
#                   value : []
#               };
#
#
#
#
#
#               // This method is responsible for drawing the graph, returns the drawn network
#               function drawGraph() {
#                   var container = document.getElementById('mynetwork');
#
#
#
#                   // parsing and collecting nodes and edges from the python
#                   nodes = new vis.DataSet([{"color": "#FFA07A", "id": "StopEvent", "label": "StopEvent", "shape": "ellipse"}, {"color": "#ADD8E6", "id": "_done", "label": "_done", "shape": "box"}, {"color": "#ADD8E6", "id": "generate_response", "label": "generate_response", "shape": "box"}, {"color": "#90EE90", "id": "TextToSQLEvent", "label": "TextToSQLEvent", "shape": "ellipse"}, {"color": "#ADD8E6", "id": "generate_sql", "label": "generate_sql", "shape": "box"}, {"color": "#90EE90", "id": "TableRetrieveEvent", "label": "TableRetrieveEvent", "shape": "ellipse"}, {"color": "#ADD8E6", "id": "retrieve_tables", "label": "retrieve_tables", "shape": "box"}, {"color": "#E27AFF", "id": "StartEvent", "label": "StartEvent", "shape": "ellipse"}]);
#                   edges = new vis.DataSet([{"arrows": "to", "from": "StopEvent", "to": "_done"}, {"arrows": "to", "from": "StopEvent", "to": "_done"}, {"arrows": "to", "from": "generate_response", "to": "StopEvent"}, {"arrows": "to", "from": "TextToSQLEvent", "to": "generate_response"}, {"arrows": "to", "from": "generate_sql", "to": "TextToSQLEvent"}, {"arrows": "to", "from": "TableRetrieveEvent", "to": "generate_sql"}, {"arrows": "to", "from": "retrieve_tables", "to": "TableRetrieveEvent"}, {"arrows": "to", "from": "StartEvent", "to": "retrieve_tables"}]);
#
#                   nodeColors = {};
#                   allNodes = nodes.get({ returnType: "Object" });
#                   for (nodeId in allNodes) {
#                     nodeColors[nodeId] = allNodes[nodeId].color;
#                   }
#                   allEdges = edges.get({ returnType: "Object" });
#                   // adding nodes and edges to the graph
#                   data = {nodes: nodes, edges: edges};
#
#                   var options = {
#     "configure": {
#         "enabled": false
#     },
#     "edges": {
#         "color": {
#             "inherit": true
#         },
#         "smooth": {
#             "enabled": true,
#             "type": "dynamic"
#         }
#     },
#     "interaction": {
#         "dragNodes": true,
#         "hideEdgesOnDrag": false,
#         "hideNodesOnDrag": false
#     },
#     "physics": {
#         "enabled": true,
#         "stabilization": {
#             "enabled": true,
#             "fit": true,
#             "iterations": 1000,
#             "onlyDynamicEdges": false,
#             "updateInterval": 50
#         }
#     }
# };
#
#
#
#
#
#
#                   network = new vis.Network(container, data, options);
#
#
#
#
#
#
#
#
#
#
#                   return network;
#
#               }
#               drawGraph();
#         </script>
#     </body>
# </html>

# %% [markdown]
# ### Run Some Queries!
#
# Now we're ready to run some queries across this entire workflow.

# %%
workflow = TextToSQLWorkflow1(
    obj_retriever,
    text2sql_prompt,
    sql_retriever,
    response_synthesis_prompt,
    llm,
    timeout=300,
    verbose=True,
)

# %%
response = await workflow.run(
    query="What was the year that The Notorious B.I.G was signed to Bad Boy?"
)
print(str(response))
# Out:
# Running step retrieve_tables
# Step retrieve_tables produced event TableRetrieveEvent
# Running step generate_sql
# Step generate_sql produced event TextToSQLEvent
# Running step generate_response
# Step generate_response produced event StopEvent
# assistant: The year that The Notorious B.I.G. was signed to Bad Boy Records was 1993.

# %%
response = await workflow.run(
    query="Who won best director in the 1972 academy awards"
)
print(str(response))
# Out:
# Running step retrieve_tables
# Step retrieve_tables produced event TableRetrieveEvent
# Running step generate_sql
# Step generate_sql produced event TextToSQLEvent
# Running step generate_response
# Step generate_response produced event StopEvent
# assistant: It appears there was no winner listed for the Best Director category in the 1972 Academy Awards based on the provided query results.

# %%
response = await workflow.run(query="What was the term of Pasquale Preziosa?")
print(str(response))
# Out:
# Running step retrieve_tables
# Step retrieve_tables produced event TableRetrieveEvent
# Running step generate_sql
# Step generate_sql produced event TextToSQLEvent
# Running step generate_response
# Step generate_response produced event StopEvent
# assistant: The query you've provided does not return any results. It appears that there are no records in the AcademyAwardActressNominations table that match all the specified criteria, which are:
#
# - Film: 'The Passion of the Christ'
# - Result: 'Nominee'
# - Award: 'Best Supporting Actress'
# - Film: 'The Passion of the Christ' (which is redundant as it's repeated and would normally be assumed to be a typo or a mistake)
#
# Therefore, there is no term associated with Pasquale Preziosa that can be retrieved from this specific query. If you are looking for information about Pasquale Preziosa's term, it seems that this data is not available in the context of the Academy Award nominations for 'The Passion of the Christ'. You may need to consult a different data source or clarify the specific information you are seeking.

# %% [markdown]
# ## 2. Advanced Capability 2: Text-to-SQL with Query-Time Row Retrieval (along with Table Retrieval)
#
# One problem in the previous example is that if the user asks a query that asks for "The Notorious BIG" but the artist is stored as "The Notorious B.I.G", then the generated SELECT statement will likely not return any matches.
#
# We can alleviate this problem by fetching a small number of example rows per table. A naive option would be to just take the first k rows. Instead, we embed, index, and retrieve k relevant rows given the user query to give the text-to-SQL LLM the most contextually relevant information for SQL generation.
#
# We now extend our workflow.

# %% [markdown]
# ### Index Each Table
#
# We embed/index the rows of each table, resulting in one index per table.

# %%
from llama_index.core import VectorStoreIndex, load_index_from_storage
from sqlalchemy import text
from llama_index.core.schema import TextNode
from llama_index.core import StorageContext
import os
from pathlib import Path
from typing import Dict


def index_all_tables(
    sql_database: SQLDatabase, table_index_dir: str = "table_index_dir"
) -> Dict[str, VectorStoreIndex]:
    """Index all tables."""
    if not Path(table_index_dir).exists():
        os.makedirs(table_index_dir)

    vector_index_dict = {}
    engine = sql_database.engine
    for table_name in sql_database.get_usable_table_names():
        print(f"Indexing rows in table: {table_name}")
        if not os.path.exists(f"{table_index_dir}/{table_name}"):
            # get all rows from table
            with engine.connect() as conn:
                cursor = conn.execute(text(f'SELECT * FROM "{table_name}"'))
                result = cursor.fetchall()
                row_tups = []
                for row in result:
                    row_tups.append(tuple(row))

            # index each row, put into vector store index
            nodes = [TextNode(text=str(t)) for t in row_tups]

            # put into vector store index (use OpenAIEmbeddings by default)
            index = VectorStoreIndex(nodes)

            # save index
            index.set_index_id("vector_index")
            index.storage_context.persist(f"{table_index_dir}/{table_name}")
        else:
            # rebuild storage context
            storage_context = StorageContext.from_defaults(
                persist_dir=f"{table_index_dir}/{table_name}"
            )
            # load index
            index = load_index_from_storage(
                storage_context, index_id="vector_index"
            )
        vector_index_dict[table_name] = index

    return vector_index_dict


vector_index_dict = index_all_tables(sql_database)
# Out:
# Indexing rows in table: AcademyAwardActressNominations
# Indexing rows in table: AirfieldLocationInfo
# Indexing rows in table: AlbumChartPositions
# Indexing rows in table: AwardsNomineesResults
# Indexing rows in table: BBC_Radio_Financials
# Indexing rows in table: BadBoyAlbums
# Indexing rows in table: BoxingMatchResults
# Indexing rows in table: Cancer_Gene_Functions
# Indexing rows in table: ClimateMonthlyAverages
# Indexing rows in table: ClubPerformanceStats
# Indexing rows in table: DistrictPopulationDensity
# Indexing rows in table: ExperimentTimeline
# Indexing rows in table: FIFA_World_Cup_Group_Stage_Results
# Indexing rows in table: FilmTitlesAndPerformances
# Indexing rows in table: FootballSeasonResults
# Indexing rows in table: GrammyAwardsNominees
# Indexing rows in table: HorseRaceWinners
# Indexing rows in table: KodachromeFilmHistory
# Indexing rows in table: LanguagePhrases
# Indexing rows in table: LocalGovernmentLeadershipTerms
# Indexing rows in table: MPOfficeSuccessions
# Indexing rows in table: MissingPersonsIncidents
# Indexing rows in table: MonthlyClimateStats
# Indexing rows in table: MonthlyWeatherStats
# Indexing rows in table: MunicipalityBoundaryChanges
# Indexing rows in table: MusicChartPositions
# Indexing rows in table: NM_ExecutiveOfficerList
# Indexing rows in table: ProbabilityEncodingTable
# Indexing rows in table: RadioStationFrequencyInfo
# Indexing rows in table: SchoolDistrictInfo
# Indexing rows in table: TheatreAwardsNominees
# Indexing rows in table: TrafficAccidentStats
# Indexing rows in table: VoterBreakdownByParty
# Indexing rows in table: VoterPartyBreakdown

# %% [markdown]
# ### Define Expanded Table Parsing
#
# We expand the capability of our table parsing to not only return the relevant table schemas, but also return relevant rows per table schema.
#
# It now takes in both `table_schema_objs` (output of table retriever), but also the original `query_str` which will then be used for vector retrieval of relevant rows.

# %%
from llama_index.core.retrievers import SQLRetriever
from typing import List

sql_retriever = SQLRetriever(sql_database)


def get_table_context_and_rows_str(
    query_str: str,
    table_schema_objs: List[SQLTableSchema],
    verbose: bool = False,
):
    """Get table context string."""
    context_strs = []
    for table_schema_obj in table_schema_objs:
        # first append table info + additional context
        table_info = sql_database.get_single_table_info(
            table_schema_obj.table_name
        )
        if table_schema_obj.context_str:
            table_opt_context = " The table description is: "
            table_opt_context += table_schema_obj.context_str
            table_info += table_opt_context

        # also lookup vector index to return relevant table rows
        vector_retriever = vector_index_dict[
            table_schema_obj.table_name
        ].as_retriever(similarity_top_k=2)
        relevant_nodes = vector_retriever.retrieve(query_str)
        if len(relevant_nodes) > 0:
            table_row_context = "\nHere are some relevant example rows (values in the same order as columns above)\n"
            for node in relevant_nodes:
                table_row_context += str(node.get_content()) + "\n"
            table_info += table_row_context

        if verbose:
            print(f"> Table Info: {table_info}")

        context_strs.append(table_info)
    return "\n\n".join(context_strs)

# %% [markdown]
# ### Define Expanded Workflow
#
# We re-use the workflow in section 1, but with an upgraded SQL parsing step after text-to-SQL generation.
#
# It is very easy to subclass and extend an existing workflow, and customizing existing steps to be more advanced. Here we define a new worfklow that overrides the existing `retrieve_tables` step in order to return the relevant rows.

# %%
from llama_index.core.workflow import (
    Workflow,
    StartEvent,
    StopEvent,
    step,
    Context,
    Event,
)


class TextToSQLWorkflow2(TextToSQLWorkflow1):
    """Text-to-SQL Workflow that does query-time row AND table retrieval."""

    @step
    def retrieve_tables(
        self, ctx: Context, ev: StartEvent
    ) -> TableRetrieveEvent:
        """Retrieve tables."""
        table_schema_objs = self.obj_retriever.retrieve(ev.query)
        table_context_str = get_table_context_and_rows_str(
            ev.query, table_schema_objs, verbose=self._verbose
        )
        return TableRetrieveEvent(
            table_context_str=table_context_str, query=ev.query
        )

# %% [markdown]
# Since the overall sequence of steps is the same, the graph should look the same.

# %%
from llama_index.utils.workflow import draw_all_possible_flows

draw_all_possible_flows(
    TextToSQLWorkflow2, filename="text_to_sql_table_retrieval.html"
)
# Out:
# text_to_sql_table_retrieval.html

# %% [markdown]
# ### Run Some Queries
#
# We can now ask about relevant entries even if it doesn't exactly match the entry in the database.

# %%
workflow2 = TextToSQLWorkflow2(
    obj_retriever,
    text2sql_prompt,
    sql_retriever,
    response_synthesis_prompt,
    llm,
    timeout=300,
    verbose=True,
)

# %%
response = await workflow2.run(
    query="What was the year that The Notorious BIG was signed to Bad Boy?"
)
print(str(response))
# Out:
# Running step retrieve_tables
# > Table Info: Table 'BadBoyAlbums' has columns: Act (VARCHAR), Year_signed (INTEGER), _Albums_released_under_Bad_Boy (VARCHAR), . The table description is: List of artists signed to Bad Boy Records and the number of albums released under the label.
# Here are some relevant example rows (values in the same order as columns above)
# ('The Notorious B.I.G', 1993, '5')
# ('The Hitmen', 1993, '–')
#
# > Table Info: Table 'AlbumChartPositions' has columns: Year (INTEGER), Title (VARCHAR), Chart_Positions_UK (VARCHAR), Chart_Positions_US (VARCHAR), Chart_Positions_NL (VARCHAR), Comments (VARCHAR), . The table description is: Chart positions of albums by year, including UK, US, and NL rankings, and comments.
# Here are some relevant example rows (values in the same order as columns above)
# (1977, 'Novella', '–', '46', '–', '1977 (January in US, August in UK, as the band moved to the Warner Bros Music Group)')
# (1978, 'A Song for All Seasons', '35', '58', '–', 'UK:Silver')
#
# > Table Info: Table 'FootballSeasonResults' has columns: Year (INTEGER), W (VARCHAR), L (VARCHAR), T (VARCHAR), Finish (VARCHAR), Coach (VARCHAR), . The table description is: Yearly football team performance statistics, including wins, losses, ties, finishes, and coach information.
# Here are some relevant example rows (values in the same order as columns above)
# (1910, '11', '0', '1', None, 'Earl Ball')
# (1918, 'did not play', 'did not play', 'did not play', 'did not play', 'did not play')
#
# Step retrieve_tables produced event TableRetrieveEvent
# Running step generate_sql
# Step generate_sql produced event TextToSQLEvent
# Running step generate_response
# Step generate_response produced event StopEvent
# assistant: The Notorious BIG was signed to Bad Boy Records in the year 1993.
